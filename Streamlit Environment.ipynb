# %% [markdown]
# ### Steps to setup Streamlit Environment:

# %% [markdown]
# ##### Install Virtual ENV
#
# * pip install virtualenv
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Create on foldar in dir for streamlit
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Run this command to start virtualenv streamlitenv
#
# * Command: cd Badal\Model\streamlit\virtual streamlitenv
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Active the env
# * Command : cd Badal\Model\streamlit\streamlitenv\Scripts\activate
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### install streamlit
# * Commands : pip install streamlit
# ![image.png](attachment:image.png)

# %% [markdown]
# #### To Start Streamlit localhost
#
# * Command : streamlit hello
# ![image.png](attachment:image.png)

# %%
##### To run the .py file
* Command : streamlit run app.py
